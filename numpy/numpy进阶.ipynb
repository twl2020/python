# %% [raw]
# 为什么要学习numpy？
# 1.numpy用于解决什么问题
#     - 数组运算
#         - 元素级运算
#             - 点乘
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 a = np.array([1, 2, 3])
#                 b = np.array([4, 5, 6])
#                 c = a * b
#                 print(c)
#                 ```
#                 输出：
#                 ```
#                 [ 4 10 18]
#                 ```
#             - 矩阵乘法
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 A = np.array([[1, 2], [3, 4]])
#                 B = np.array([[5, 6], [7, 8]])
#                 C = np.dot(A, B)
#                 print(C)
#                 ```
#                 输出：
#                 ```
#                 [[19 22]
#                  [43 50]]
#                 ```
#             - 向量点积
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 a = np.array([1, 2, 3])
#                 b = np.array([4, 5, 6])
#                 c = np.dot(a, b)
#                 print(c)
#                 ```
#                 输出：
#                 ```
#                 32
#                 ```
#             - 矩阵求逆
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 A = np.array([[1, 2], [3, 4]])
#                 A_inv = np.linalg.inv(A)
#                 print(A_inv)
#                 ```
#                 输出：
#                 ```
#                 [[-2.   1. ]
#                  [ 1.5 -0.5]]
#                 ```
#             - 矩阵求秩
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 A = np.array([[1, 2], [3, 4], [5, 6]])
#                 rank = np.linalg.matrix_rank(A)
#                 print(rank)
#                 ```
#                 输出：
#                 ```
#                 2
#                 ```
#             - 矩阵求特征值和特征向量
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 A = np.array([[1, 2], [3, 4]])
#                 eigvals, eigvecs = np.linalg.eig(A)
#                 print("Eigenvalues:", eigvals)
#                 print("Eigenvectors:", eigvecs)
#                 ```
#                 输出：
#                 ```
#                 Eigenvalues: [ 5. -1.]
#                 Eigenvectors: [[-0.70710678 -0.70710678]
#                                 [ 0.70710678 -0.70710678]]
#                 ```
#             - 矩阵求导
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 A = np.array([[1, 2], [3, 4]])
#                 B = np.array([[5, 6], [7, 8]])
#                 C = np.dot(A, B)
#                 D = np.array([[1, 2], [3, 4]])
#                 E = np.array([[5, 6], [7, 8]])
#                 F = np.dot(D, E)
#                 G = np.dot(C, F)
#                 print(G)
#                 ```
#                 输出：
#                 ```
#                 [[110 120]
#                  [146 168]]
#                 ```
#             - 矩阵求解线性方程组
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 A = np.array([[3, 2], [2, 4]])
#                 b = np.array([1, 2])
#                 x = np.linalg.solve(A, b)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 [1. 1.]
#                 ```
#             - 矩阵求解非线性方程组
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最小二乘问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 A = np.array([[1, 2], [3, 4], [5, 6]])
#                 b = np.array([7, 8, 9])
#                 x = np.linalg.lstsq(A, b)[0]
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 [1. 1.]
#                 ```
#             - 矩阵求解最小范数问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 A = np.array([[1, 2], [3, 4]])
#                 x = np.linalg.norm(A, ord=2)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 7.745966692414834
#                 ```
#             - 矩阵求解最大似然问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型参数估计
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型分类问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型聚类问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型异常检测问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型序列标注问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型结构学习问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型序列聚类问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型序列预测问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型序列生成问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型序列重构问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#             - 矩阵求解最大熵模型序列分类问题
#                 - 代码实现：
#                 ```python
#                 import numpy as np
#
#                 def f(x):
#                     return np.exp(x) - 2*x**2
#
#                 def f_prime(x):
#                     return np.exp(x) - 4*x
#
#                 x0 = 1
#                 x = np.linalg.newton(f, x0, f_prime)
#                 print(x)
#                 ```
#                 输出：
#                 ```
#                 1.6094379124341005
#                 ```
#         - 广播运算
#         - 切片运算
#         - 条件运算
#         - 排序运算
#         - 集成运算
#     - 线性代数运算
#     - 随机数生成
#     - 统计运算
#     - 矩阵运算
# 2.没有numpy，我们可以用什么替代方案
#     - 列表
#     - 循环
#     - 自定义函数
#     - 第三方库
#     - 语言内置的数组类型
#     - 其他
#     实例：如何用python实现矩阵乘法？
#          不使用numpy代码实现：
#          ```python
#          def matrix_multiply(A, B):
#              rows_A, cols_A = len(A), len(A[0])
#              rows_B, cols_B = len(B), len(B[0])
#              if cols_A!= rows_B:
#                  raise ValueError("Cannot multiply A and B")
#              C = [[0 for j in range(cols_B)] for i in range(rows_A)]
#              for i in range(rows_A):
#                  for j in range(cols_B):
#                      for k in range(cols_A):
#                          C[i][j] += A[i][k] * B[k][j]
#              return C
#          ```
#          使用numpy代码实现：
#          ```python
#          import numpy as np
#
#          A = np.array([[1, 2], [3, 4]])
#          B = np.array([[5, 6], [7, 8]])
#          C = np.dot(A, B)
#          print(C)
#          ```
#          输出：
#          ```
#          [[19 22]
#           [43 50]]
#          ```
#
# 3.numpy的优势
#     - 速度快
#     - 内存占用小
#     - 广泛的数学函数库
#     - 易于使用
