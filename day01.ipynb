# %% [markdown]
# ## 环境安装
# ```shell
# 1.安装pycharm
# 2.安装anaconda（直接安装到c盘）
#   2.1 安装选择 just me，并选择添加 path 到环境变量中
#   2.2 如何完全卸载，安装 anaconda-clean
# 3.安装git
#   3.1 配置ssh
#     3.1.1 生成ssh key（ssh-keygen -t rsa -C "xxx@xxx.com"）
#     3.1.2 复制生成的key
#     3.1.3 在github账号上添加公钥
#     3.1.4 验证是否设置成功 ssh -T git@github.com
#     3.1.5 clone仓库的时候要使用ssh的url
# ```
# ## python基础 (https://docs.python.org/zh-cn/3.11/tutorial/introduction.html)
# ```shell
# 1.本语言的命名源自 BBC 的 “Monty Python 飞行马戏团”，与爬行动物无关（Python 原义为“蟒蛇”）
# 2.python的解释器 解释器的操作方式类似 Unix Shell：用与 tty 设备关联的标准输入调用时，
#   可以交互式地读取和执行命令；以文件名参数，或标准输入文件调用时，则读取并执行文件中的 脚本
# 3.另一种启动解释器的方式是 python -c command [arg] ...，这将执行 command 中的语句，相当于 shell 的 -c 选项。  python -c "print(min(1,2))"
#   由于 Python 语句经常包含空格或其他会被 shell 特殊对待的字符，通常建议用引号   将整个 command 括起来。
#   Python 模块也可以当作脚本使用。输入：python -m module [arg] ...，会执行 module 的源文件，这跟在命令行把路径写全了一样。  python -m main
#   在交互模式下运行脚本文件，只要在脚本名称参数前，加上选项 -i 就可以了。  python -i main.py
# ```
# ```python
# # -*- coding: encoding -*-
# """
# 默认情况下，Python 源码文件的编码是 UTF-8。如果不使用默认编码，则要声明文件的编码，文件的 第一 行要写成特殊注释
# # -*- coding: encoding -*-
# # -*- coding: cp1252 -*-
#
# 第一行 的规则也有一种例外情况，源码以 UNIX "shebang" 行 开头。此时，编码声明要写在文件的第二行
# #!/usr/bin/env python3
# # -*- coding: cp1252 -*-
# """
# ```
# ```shell
#
# 1.Python 程序的基本组成部分是模块（module）、函数（function）、类（class）和语句（statement）。模块是 Python 代码的基本单位，包含了 Python 代码定义和执行的逻辑。模块可以被导入（import）、使用（使用 from 模块名 import 成员名 导入模块中的成员）、重新定义（使用 as 给模块取别名）、修改（使用 reload() 函数重新加载模块）、执行（使用 exec() 函数执行模块中的代码）。模块的名称通常是文件名（不带 .py 扩展名）。
#
# 2.函数是模块的组成部分，它定义了一个输入（参数）和输出（返回值）的计算过程。函数可以被调用（调用时传入参数）、定义（定义时定义参数和返回值）、修改（使用 def 语句重新定义）、删除（使用 del 语句删除）。函数的名称通常是小写字母，多个单词用下划线连接。
#
# 3.类是模块的组成部分，它定义了对象的属性和行为。类可以被定义（使用 class 语句定义）、实例化（使用类名() 创建对象）、修改（使用属性赋值语句修改对象属性）、删除（使用 del 语句删除对象）。类名通常是大写字母，多个单词用下划线连接。
#
# 4.语句是 Python 代码的基本组成部分，它是一条或多条 Python 代码的集合。语句可以是表达式（表达式的值是计算结果）、赋值语句（将值赋给变量）、条件语句（根据条件执行不同的代码块）、循环语句（重复执行代码块）、打印语句（输出值到屏幕或文件）、输入语句（从键盘输入值）、函数调用语句（调用函数）、类实例化语句（创建类的实例）、异常处理语句（处理异常）。
#
# 5.Python 程序的执行顺序是从上到下，从左到右。程序的执行可以暂停并等待用户输入，也可以在程序执行过程中随时中断。程序的执行可以被中断，并在下次继续执行。
#
# 6.Python 程序的语法遵循“缩进”规则，即代码块（如函数或类定义）的第一行必须缩进。缩进的空格数是可变的，但必须相同。
#
# 7.Python 程序的注释以 # 开头，注释可以单独占一行，也可以与代码混合在一起。
#
# 8.Python 程序的变量名必须是有效的标识符，即由字母、数字、下划线组成的序列，且不能以数字开头。
#
# 9.Python 程序的标识符的命名规范：
#    - 变量名：小写字母、下划线连接
#    - 函数名：小写字母、下划线连接
#    - 类名：大写字母、下划线连接
#    - 模块名：小写字母、下划线连接
#    - 常量名：全部大写字母、下划线连接
#
# 10.Python 程序的运算符有：
#    - 算术运算符：+、-、*、/、//、%、**
#    - 赋值运算符：=、+=、-=、*=、/=、%=、**=
#    - 比较运算符：==、!=、>、<、>=、<=
#    - 逻辑运算符：and、or、not
#    - 位运算符：&、|、^、~、<<、>>
#    - 成员运算符：in、not in
#    - 身份运算符：is、is not
#
# 11.Python 程序的控制流语句有：
#    - if 语句
#    - for 语句
#    - while 语句
#    - try-except 语句
#    - with 语句
#
# 12.Python 程序的输入输出有：
#    - 打印输出：print() 函数
#    - 输入输出：input() 函数
#    - 文件输入输出：open() 函数
#
# 13.Python 程序的异常处理有：
#    - try-except 语句
#    - raise 语句
#    - assert 语句
#
# 14.Python 程序的调试有：
#    - pdb 调试器
#    - 单元测试
#
# 15.Python 程序的编码风格有：
#    - PEP 8 编码风格指南
#    - Google Python 风格指南 (https://zh-google-styleguide.readthedocs.io/en/latest/google-python-styleguide/contents/)
#    - 其他编码风格指南
# 16.Python 程序的运行环境有：
#    - Python 解释器
#    - Python 标准库
#    - 第三方库
#    - 虚拟环境
#    - 集成开发环境（IDE）
# ```

# %% [markdown]
# ## 第一个Python程序
# ```python
# # 第一个Python程序
# print("Hello, World!")
# ```
# - 输出：Hello, World!

# %% [markdown]
# 数据类型详解：
# - 整数（int）：整数类型用于存储整数值，包括正整数、负整数、零。
# - 浮点数（float）：浮点数类型用于存储小数值，包括正数、负数、零、无限大。
# - 字符串（str）：字符串类型用于存储文本数据，包括单个字符和多个字符。
# - 布尔值（bool）：布尔值类型用于存储布尔值，包括 True 和 False。
# - 列表（list）：列表类型用于存储一系列值，这些值可以是不同类型的数据。列表可以包含重复的值。
# - 元组（tuple）：元组类型用于存储一系列值，这些值可以是不同类型的数据。元组中的值不能被修改。
# - 字典（dict）：字典类型用于存储一系列键值对，其中每个键都对应一个值。字典中的键必须是唯一的。
# - 集合（set）：集合类型用于存储一系列值，这些值不能重复。集合中的值可以是不同类型的数据。
# - 类型转换：可以将不同类型的数据转换为相同类型的数据。

# %% [markdown]
# ## 变量
# ```python
# # 变量
# a = 10
# b = 20
# c = a + b
# print(c)
# ```
# - 变量名：由字母、数字、下划线组成的序列，且不能以数字开头。
# - 变量类型：变量可以存储不同类型的数据，包括整数、浮点数、字符串、布尔值、列表、元组、字典、集合。
# - 变量作用域：变量的作用域决定了变量的生命周期，在程序运行期间，变量的作用域可以是全局作用域、局部作用域或嵌套作用域。
# - 变量命名规范：
#    - 变量名：小写字母、下划线连接
#    - 常量名：全部大写字母、下划线连接
# - 变量赋值：
#    - 直接赋值：将一个值赋给一个变量，如 a = 10。
#    - 表达式赋值：将一个表达式的计算结果赋给一个变量，如 a = 10 + 20。
#    - 多重赋值：将多个变量的值同时赋值，如 a, b = 10, 20。
# - 变量删除：del 语句可以删除一个变量，如 del a。
# - 变量作用域：
#    - 全局作用域：全局变量可以被所有的函数、模块和类访问，全局变量的生命周期从定义开始，直到程序结束。
#    - 局部作用域：局部变量只能被当前函数、模块或类访问，局部变量的生命周期从函数或模块被调用开始，直到函数或模块返回或程序结束。
#    - 嵌套作用域：嵌套作用域是指一个作用域中包含另一个作用域，如函数内部定义的函数。
#       - 内层作用域可以访问外层作用域的变量，但外层作用域不能访问内层作用域的变量。
#       - 内层作用域可以修改外层作用域的变量，但外层作用域不能修改内层作用域的变量。
#    - 作用域查找顺序：
#       - 局部作用域
#       - 内层作用域（如果有）
#       - 全局作用域
#       - 内层作用域（如果有）
#    - global 语句：使用 global 语句可以在函数或模块中声明全局变量，使其可以在函数或模块的局部作用域中访问。
#       - 注意：global 语句只能在函数或模块的局部作用域中使用。
#             - 内层作用域不能使用 global 语句声明全局变量。
#             - 外层作用域不能使用 global 语句声明局部变量。
#       - 示例：
#          ```python
#          x = 10
#          def outer():
#              global x
#              x = 20
#              print(x)
#          outer()
#          print(x)
#          ```
#          输出：
#          ```python
#          20
#          20
#          ```
#          说明：
#          - 第 1 行：声明全局变量 x。
#          - 第 3 行：声明函数 outer，函数内部修改全局变量 x。
#          - 第 4 行：使用 global 语句声明变量 x，使其可以在 outer 函数中访问。
#          - 第 5 行：调用 outer 函数。
#          - 第 6 行：打印变量 x 的值，输出为 20。
#          - 第 7 行：打印变量 x 的值，输出为 20。
#          - 说明：
#             - 变量 x 的值在 outer 函数中被修改为 20，并在函数返回后，被修改为 20。
#             - 由于变量 x 的作用域是全局作用域，所以在 outer 函数中修改变量 x，会影响全局变量 x。
#             - 由于变量 x 的作用域是全局作用域，所以在 outer 函数中声明变量 x，会使其成为全局变量。
#             - 由于变量 x 的作用域是全局作用域，所以在 outer 函数中声明变量 x，会使其可以在函数的局部作用域中访问。
#             - 由于变量 x 的作用域是全局作用域，所以在 outer 函数中声明变量 x，会使其可以在函数的内层作用域中访问。
#             - 由于变量 x 的作用域是全局作用域，所以在 outer 函数中声明变量 x，会使其可以在函数的外层作用域中访问。
#    - nonlocal 语句：使用 nonlocal 语句可以在函数或模块中声明外层作用域的变量，使其可以在函数或模块的嵌套作用域中访问。
#       - 注意：nonlocal 语句只能在函数或模块的嵌套作用域中使用。
#             - 内层作用域不能使用 nonlocal 语句声明外层作用域的变量。
#             - 外层作用域不能使用 nonlocal 语句声明内层作用域的变量。
#       - 示例：
#          ```python
#          def outer():
#              y = 20
#              def inner():
#                  nonlocal y
#                  y = 30
#                  print(y)
#              inner()
#              print(y)
#          outer()
#          ```
#          输出：
#          ```python
#          30
#          20
#          ```
#          说明：
#          - 第 1 行：声明全局变量 x。
#          - 第 3 行：声明函数 outer，函数内部定义函数 inner。
#          - 第 4 行：声明局部变量 y，并赋值为 20。
#          - 第 6 行：使用 nonlocal 语句声明变量 y，使其可以在 inner 函数中访问。
#          - 第 7 行：修改变量 y 的值为 30。
#          - 第 8 行：调用 inner 函数。
#          - 第 9 行：打印变量 y 的值，输出为 30。
#          - 第 10 行：打印变量 y 的值，输出为 20。
#          - 第 11 行：调用 outer 函数。
#          - 第 12 行：打印变量 y 的值，输出为 20。
#          - 说明：
#             - 变量 y 的值在 inner 函数中被修改为 30，并在函数返回后，被修改为 20。
#             - 变量 y 的值在 outer 函数中被修改为 20，并在函数返回后，被修改为 20。
#             - 由于变量 y 的作用域是局部作用域，所以在 inner 函数中修改变量 y，不会影响外层作用域的变量 y。
#             - 由于变量 y 的作用域是局部作用域，所以在 outer 函数中修改变量 y，不会影响 inner 函数的变量 y。
#             - 由于变量 y 的作用域是嵌套作用域，所以 inner 函数可以访问外层作用域的变量 y。
#             - 由于变量 y 的作用域是嵌套作用域，所以 outer 函数可以访问 inner 函数的变量 y。
#     - locals() 函数：locals() 函数可以获取当前作用域中的所有变量。
#     - globals() 函数：globals() 函数可以获取全局作用域中的所有变量。
#         - 注意：globals() 函数只能在模块的全局作用域中使用。
#                 - 不能在函数或类中使用 globals() 函数。
#                         - 示例：
#                             ```python
#                             x = 10
#                             def outer():
#                                 y = 20
#                                 def inner():
#                                     print(globals())
#                                 inner()
#                             outer()
#                             ```
#                             输出：
#                             ```python
#                             {'__name__': '__main__', 'x': 10, 'outer': <function outer at 0x000001B7F2F0D1F0>, 'inner': <function inner at 0x000001B7F2F0D288>}
#                             ```
#                             说明：
#                             - 第 1 行：声明全局变量 x。
#                             - 第 3 行：声明函数 outer，函数内部定义函数 inner。
#                             - 第 4 行：声明局部变量 y，并赋值为 20。
#                             - 第 6 行：调用 inner 函数。
#                             - 第 7 行：打印 globals() 函数的返回值，输出为字典。
#                             - 说明：
#                                 - globals() 函数返回当前作用域中的所有变量，包括全局变量和局部变量。
#                                 - 由于 inner 函数是在 outer 函数中定义的，所以 inner 函数的作用域是局部作用域。
#                                 - 由于 inner 函数的作用域是局部作用域，所以 globals() 函数只能在 inner 函数中使用。
#                                 - 由于 inner 函数的作用域是局部作用域，所以 globals() 函数返回的字典中只包含 inner 函数的局部变量。
#                                 - 由于 outer 函数是在全局作用域中定义的，所以 outer 函数的作用域是全局作用域。
#                                 - 由于 outer 函数的作用域是全局作用域，所以 globals() 函数返回的字典中包含全局变量 x。

# %% [markdown]
# ## 条件语句
# ```python
# # 条件语句
# a = 10
# b = 20
# if a > b:
#     print("a is greater than b")
# elif a == b:
#     print("a is equal to b")
# else:
#     print("a is less than b")
# ```
# - if 语句：if 语句用于条件判断，根据判断条件是否成立，执行对应的代码块。
# - if...else 语句：if...else 语句用于条件判断，根据判断条件是否成立，执行对应的代码块。
# - if...elif...else 语句：if...elif...else 语句用于条件判断，根据判断条件是否成立，执行对应的代码块。
# - 条件表达式：条件表达式可以作为 if 语句的判断条件，其语法格式为：
#    - 表达式1 if 条件 else 表达式2
# - 条件运算符：
#    - 等于：==
#    - 不等于：!=
#    - 大于：>
#    - 小于：<
#    - 大于等于：>=
#    - 小于等于：<=

# %% [markdown]
# 循环语句：
# - while 循环：while 循环用于重复执行一段代码，直到条件表达式为 False。
# - for 循环：for 循环用于遍历一个序列（如列表、元组、字符串）中的元素，重复执行一段代码。
# - 循环控制语句：
#    - break 语句：break 语句用于终止当前循环。
#    - continue 语句：continue 语句用于跳过当前循环的剩余语句，直接开始下一轮循环。
#    - pass 语句：pass 语句用于占位，表示什么都不做。

# %% [markdown]
# 函数：
# - 函数定义：函数定义用于创建函数，语法格式为：
#    - def 函数名(参数列表):
#       - 函数体
# - 函数调用：函数调用用于调用函数，语法格式为：
#    - 函数名(参数列表)
# - 位置参数：位置参数用于将参数按照顺序传递给函数，语法格式为：
#    - 函数名(参数1, 参数2, 参数3)
# - 关键字参数：关键字参数用于将参数按照名称传递给函数，语法格式为：
#    - 函数名(参数名1=值1, 参数名2=值2, 参数名3=值3)
# - 默认参数：默认参数用于设置参数的默认值，语法格式为：
#    - def 函数名(参数列表, 默认参数=默认值)
# - 可变参位置数：可变参数用于将参数个数不定的参数传递给函数，语法格式为：
#    - def 函数名(参数列表, *args)
#    - 示例：
#       ```python
#       def my_sum(*args):
#           result = 0
#           for i in args:
#               result += i
#           return result
#       print(my_sum(1, 2, 3, 4, 5))
#       ```
#       输出：
#       ```python
#       15
#       ```
#       说明：
#       - 第 1 行：定义函数 my_sum，参数列表中包含可变参数 args。
#       - 第 3 行：定义变量 result，并初始化为 0。
#       - 第 4 行：遍历可变参数 args，将每个元素的值加到变量 result 中。
#       - 第 5 行：返回变量 result 的值。
#       - 第 6 行：调用函数 my_sum，传入参数 1、2、3、4、5。
#       - 第 7 行：打印函数 my_sum 的返回值，输出为 15。
# - 可变关键字参数：关键字参数用于将参数按照名称传递给函数，语法格式为：
#    - def 函数名(参数列表, **kwargs)
#    - 示例：
#       ```python
#       def my_func(a, b, c=10, d=20):
#           print("a =", a)
#           print("b =", b)
#           print("c =", c)
#           print("d =", d)
#       my_func(10, 20, c=30, d=40)
#       ```
#       输出：
#       ```python
#       a = 10
#       b = 20
#       c = 30
#       d = 40
#       ```
#       说明：
#       - 第 1 行：定义函数 my_func，参数列表中包含关键字参数 c 和 d，默认值为 10 和 20。
#       - 第 4 行：打印函数 my_func 的参数 a、b、c、d 的值。
#       - 第 5 行：调用函数 my_func，传入参数 a=10、b=20、c=30、d=40。
#       - 第 6 行：打印函数 my_func 的返回值，输出为 None。
# - 递归函数：递归函数是指函数自己调用自己。

# %% [markdown]
# ## 异常处理
# ```python
# # 异常处理
# try:
#     a = 10 / 0
# except ZeroDivisionError:
#     print("division by zero!")
# except:
#     print("something else went wrong")
# else:
#     print("no exceptions were raised")
# finally:
#     print("cleaning up, regardless of whether an exception was raised or not")
# ```
# - try 语句：try 语句用于捕获异常，语法格式为：
#    - try:
#       - 可能引发异常的代码
#    - except 异常类型1:
#       - 异常类型1发生时执行的代码
#    - except 异常类型2:
#       - 异常类型2发生时执行的代码
#    - ...
#    - except 异常类型n:
#       - 异常类型n发生时执行的代码
#    - else:
#       - 没有异常发生时执行的代码
#    - finally:
#       - 无论是否发生异常，都会执行的代码
# - 异常类型：
#    - BaseException：所有异常的基类。
#    - Exception：常规异常，包括系统错误、断言错误等。
#    - ArithmeticError：数学计算错误。
#    - AssertionError：断言语句失败。
#    - AttributeError：对象没有这个属性。
#    - EOFError：没有内建输入，到达EOF标记。
#    - ImportError：导入模块/对象失败。
#    - IndexError：序列中没有此索引。
#    - KeyError：映射中没有这个键。
#    - KeyboardInterrupt：用户中断执行。
#    - MemoryError：内存溢出错误。
#    - NameError：未声明/初始化对象。
#    - NotImplementedError：尚未实现的方法。
#    - OSError：操作系统错误。
#    - OverflowError：数值运算超出最大限制。
#    - ReferenceError：弱引用对象没有引用。
#    - RuntimeError：一般的运行时错误。
#    - StopIteration：迭代器没有更多的值。
#    - SyntaxError：Python代码语法错误。
#    - IndentationError：缩进错误。
#    - TabError：Tab和空格混用。
#    - SystemError：一般的解释器系统错误。
#    - TypeError：对类型无效的操作。
#    - ValueError：传入无效的参数。
#    - UnicodeError：Unicode相关的错误。
#    - Warning：警告的基类。
#    - UserWarning：用户代码生成的警告。
#    - DeprecationWarning：关于被弃用的特征的警告。
#    - FutureWarning：关于构造将来语义会有改变的警告。
#    - PendingDeprecationWarning：关于特性将会被废弃的警告。
#    - RuntimeWarning：可疑的运行时行为(runtime behavior)的警告。
#    - SyntaxWarning：可疑的语法的警告。
#    - UnicodeWarning：Unicode相关的警告。
#    - ImportWarning：导入模块/对象生成的警告。
#    - UnicodeDecodeError：Unicode解码时的错误。
#    - UnicodeEncodeError：Unicode编码时的错误。
#    - UnicodeTranslateError：Unicode转换时的错误。
#       - 注意：Python 3.x 中不再支持 string.decode() 方法，请使用 bytes.decode() 方法。
#             - 示例：
#                 ```python
#                 s = "hello, world!"
#                 b = s.encode("utf-8")
#                 print(b.decode("utf-8"))
#                 ```
#                 输出：
#                 ```python
#                 hello, world!
#                 ```
#                 说明：
#                 - 第 1 行：定义字符串 s。
#                 - 第 2 行：将字符串 s 编码为 bytes。
#                 - 第 3 行：将 bytes 解码为字符串。
#   - 自定义异常：用户可以定义自己的异常，语法格式为：
#      - class 异常名称(Exception):
#         - 异常说明

# %% [markdown]
# 类：
# - 类定义：类定义用于创建类，语法格式为：
#    - class 类名:
#       - 类变量
#       - 方法定义
# - 类实例化：类实例化用于创建类的对象，语法格式为：
#    - 对象名 = 类名()
#    - 类名.类变量名 = 值
#    - 对象名.方法名(参数列表)
#    - 类名.类变量名 = 值
# - 类方法：类方法用于定义类方法，语法格式为：
#    - @classmethod
#    - def 方法名(cls, 参数列表):
#       - 函数体
# - 静态方法：静态方法用于定义静态方法，语法格式为：
#    - @staticmethod
#    - def 方法名(参数列表):
#       - 函数体
# - 实例变量：实例变量用于定义实例变量，语法格式为：
#    - self.变量名 = 值
# - 类变量：类变量用于定义类变量，语法格式为：
#    - 类名.变量名 = 值
# - 继承：继承用于创建子类，语法格式为：
#    - class 子类名(父类名):
#       - 子类变量
#       - 方法定义
# - 多继承：多继承用于创建子类，语法格式为：
#    - class 子类名(父类1, 父类2, ...):
#       - 子类变量
#       - 方法定义
# - 多态：多态用于调用父类的方法，语法格式为：
#    - 对象名.方法名(参数列表)
# - 私有属性：私有属性用于定义私有属性，语法格式为：
#    - __变量名 = 值
# - 私有方法：私有方法用于定义私有方法，语法格式为：
#    - def 方法名(self, 参数列表):
#       - 函数体
#       - 注意：私有方法只能在类的内部调用，不能在类的外部调用。
# - 特殊方法：特殊方法用于实现一些特殊功能，语法格式为：
#    - __方法名__(参数列表):
#       - 函数体
#       - 注意：特殊方法只能在类的内部调用，不能在类的外部调用。
# - 枚举类：枚举类用于定义枚举类型，语法格式为：
#    - from enum import Enum
#    - class 枚举类名(Enum):
#       - 成员变量 = 值
# - 元类：元类用于创建类，语法格式为：
#    - class 元类名(type):
#       - 类变量
#       - 方法定义
#     - 注意：元类只能用于创建类，不能用于创建对象。
# - 装饰器：装饰器用于修改函数的行为，语法格式为：
#    - @装饰器
#    - def 函数名(参数列表):
#       - 函数体
#    - 注意：装饰器只能用于修饰函数，不能用于修饰类。
#       - 示例：
#          ```python
#          def my_decorator(func):
#              def wrapper(*args, **kwargs):
#                  print("Something is happening before the function is called.")
#                  result = func(*args, **kwargs)
#                  print("Something is happening after the function is called.")
#                  return result
#              return wrapper
#
#          @my_decorator
#          def my_func(x, y):
#              return x + y
#
#          print(my_func(10, 20))
#          ```
#          输出：
#          ```python
#          Something is happening before the function is called.
#          30
#          Something is happening after the function is called.
#          ```
#          说明：
#          - 第 1 行：定义装饰器 my_decorator，用于打印信息。
#          - 第 3 行：定义函数 my_func，并使用装饰器 my_decorator 修饰。
#          - 第 6 行：调用函数 my_func，传入参数 10、20。
#          - 第 7 行：打印函数 my_func 的返回值，输出为 30。
#   - 类装饰器：类装饰器用于修改类的方法的行为，语法格式为：
#      - @classmethod
#      - @装饰器
#      - def 方法名(cls, 参数列表):
#         - 函数体
#      - 注意：类装饰器只能用于修饰类的方法，不能用于修饰函数。
#         - 示例：
#            ```python
#            class MyDecorator:
#                def __init__(self, func):
#                    self.func = func
#
#                def __call__(self, *args, **kwargs):
#                    print("Something is happening before the function is called.")
#                    result = self.func(*args, **kwargs)
#                    print("Something is happening after the function is called.")
#                    return result
#
#            @MyDecorator
#            def my_func(x, y):
#                return x + y
#
#            print(my_func(10, 20))
#            ```
#            输出：
#            ```python
#            Something is happening before the function is called.
#            30
#            Something is happening after the function is called.
#            ```
#            说明：
#            - 第 1 行：定义类装饰器 MyDecorator，用于打印信息。
#            - 第 3 行：定义函数 my_func，并使用类装饰器 MyDecorator 修饰。
#            - 第 6 行：调用函数 my_func，传入参数 10、20。
#            - 第 7 行：打印函数 my_func 的返回值，输出为 30。
#   - 静态方法装饰器：静态方法装饰器用于修改静态方法的行为，语法格式为：
#      - @staticmethod
#      - @装饰器
#      - def 方法名(参数列表):
#         - 函数体
#      - 注意：静态方法装饰器只能用于修饰静态方法，不能用于修饰类的方法。
#         - 示例：
#            ```python
#            class MyClass:
#                @staticmethod
#                @MyDecorator
#                def my_static_method(x, y):
#                    return x + y
#
#            print(MyClass.my_static_method(10, 20))
#            ```
#            输出：
#            ```python
#            Something is happening before the function is called.
#            30
#            Something is happening after the function is called.
#            ```
#            说明：
#            - 第 1 行：定义类 MyClass，并定义静态方法 my_static_method。
#            - 第 3 行：使用类装饰器 MyDecorator 修饰静态方法 my_static_method。
#            - 第 6 行：调用静态方法 my_static_method，传入参数 10、20。
#            - 第 7 行：打印函数 my_static_method 的返回值，输出为 30。
#   - 装饰器的顺序：装饰器的顺序决定了装饰器的执行顺序。
#     - 示例：
#        ```python
#        def my_decorator(func):
#            def wrapper(*args, **kwargs):
#                print("Something is happening before the function is called.")
#                result = func(*args, **kwargs)
#                print("Something is happening after the function is called.")
#                return result
#            return wrapper
#
#        @my_decorator
#        @my_decorator
#        def my_func(x, y):
#            return x + y
#
#        print(my_func(10, 20))
#        ```
#        输出：
#        ```python
#        Something is happening before the function is called.
#        Something is happening before the function is called.
#        30
#        Something is happening after the function is called.
#        Something is happening after the function is called.
#        ```
#        说明：
#        - 第 1 行：定义装饰器 my_decorator，用于打印信息。
#        - 第 3 行：定义函数 my_func，并使用装饰器 my_decorator 修饰。
#        - 第 4 行：再次使用装饰器 my_decorator 修饰函数 my_func。
#        - 第 6 行：调用函数 my_func，传入参数 10、20。
#        - 第 7 行：打印函数 my_func 的返回值，输出为 30。
